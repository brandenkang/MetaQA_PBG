# %%
import os
import shutil
import json
import h5py
import torch
import numpy as np
from pathlib import Path
from torchbiggraph.config import parse_config
from torchbiggraph.converters.importers import TSVEdgelistReader, convert_input_data
from torchbiggraph.train import train
from torchbiggraph.util import SubprocessInitializer, setup_logging

# %%
DATA_DIR = 'data/example_2'
GRAPH_PATH = DATA_DIR + '/kb.tsv'
TRAINING_PATH = DATA_DIR + '/training.tsv'
TEST_PATH = DATA_DIR + '/test.tsv'
MODEL_DIR = 'model_2'

config = dict(
    # I/O data
    entity_path=DATA_DIR,
    edge_paths=[
        DATA_DIR + '/edge_path'
    ],
    checkpoint_path=MODEL_DIR,
    # Graph structure
    entities={"all": {"num_partitions": 1}},
    relations=[
       {
            "name": "all_edges",
            "lhs": "all",
            "rhs": "all",
            "operator": "translation",
        }
    ],

    dynamic_relations=True,
    dimension=400,  
    global_emb=False,
    comparator="dot",
    num_epochs=200,
    num_uniform_negs=1000,
    loss_fn="softmax",
    lr=0.1,
    regularization_coef=1e-3,
    eval_fraction=0.2,
)

# %%
# =================================================
# 2. TRANSFORM GRAPH TO A BIGGRAPH-FRIENDLY FORMAT
# This step generates the following metadata files:

# data/example_2/entity_count_director_0.txt
# data/example_2/entity_count_director_0.json

# and this file with data:
# data/example_2/edges_partitioned/edges_0_0.h5
# =================================================
setup_logging()
config = parse_config(config)
subprocess_init = SubprocessInitializer()
input_edge_paths = [Path(GRAPH_PATH)]

convert_input_data(
    config.entities,
    config.relations,
    config.entity_path,
    config.edge_paths,
    input_edge_paths,
    TSVEdgelistReader(lhs_col=0, rel_col=1, rhs_col=2),
    dynamic_relations=config.dynamic_relations,
)
# Out:
# Found some files that indicate that the input data has already been preprocessed, not doing it again.
# These files are in: data/example_2, data/example_2/edge_path

# %%
# ===============================================
# 3. TRAIN THE EMBEDDINGS
# files generated in this step:
#
# checkpoint_version.txt
# config.json
# embeddings_all_0.v7.h5
# model.v7.h5
# training_stats.json
# ===============================================

train(config, subprocess_init=subprocess_init)
# Out:
# 2021-04-23 04:14:45,894   [Trainer-0] Loading entity counts...
# 2021-04-23 04:14:46,162   [Trainer-0] Creating workers...
# 2021-04-23 04:14:46,276   [Trainer-0] Initializing global model...
# 2021-04-23 04:14:46,324   [Trainer-0] Starting epoch 58 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:14:46,326   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:14:46,330   [Trainer-0] still in queue: 0
# 2021-04-23 04:14:46,341   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:14:46,354   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:14:48,259   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9771 , pos_rank:  242.612 , mrr:  0.26206 , r1:  0.206249 , r10:  0.357021 , r50:  0.501187 , auc:  0.865537 , count:  26948
# 2021-04-23 04:15:40,194   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.13256 , reg:  0.0862826 , violators_lhs:  5.07421 , violators_rhs:  0.102363 , count:  107793
# 2021-04-23 04:15:42,354   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9793 , pos_rank:  241.738 , mrr:  0.261784 , r1:  0.206026 , r10:  0.357893 , r50:  0.50115 , auc:  0.867319 , count:  26948
# 2021-04-23 04:15:42,372   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 51.97 s ( 0.0021 M/sec ); Eval 2*26948 edges in 4.00 s ( 0.013 M/sec ); io: 0.05 s for 72,408,184 bytes ( 1319.44 MB/sec )
# 2021-04-23 04:15:42,376   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:15:42,379   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:15:42,738   [Trainer-0] Finished epoch 58 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:15:42,739   [Trainer-0] Writing the metadata
# 2021-04-23 04:15:42,759   [Trainer-0] Writing the training stats
# 2021-04-23 04:15:42,768   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:15:42,773   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:15:42,782   [Trainer-0] Starting epoch 59 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:15:42,794   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:15:42,796   [Trainer-0] still in queue: 0
# 2021-04-23 04:15:42,798   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:15:42,799   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:15:44,240   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9666 , pos_rank:  241.608 , mrr:  0.262234 , r1:  0.206657 , r10:  0.35793 , r50:  0.501373 , auc:  0.864851 , count:  26948
# 2021-04-23 04:16:25,528   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.13177 , reg:  0.086142 , violators_lhs:  5.06849 , violators_rhs:  0.105647 , count:  107793
# 2021-04-23 04:16:26,795   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9869 , pos_rank:  241.843 , mrr:  0.262336 , r1:  0.206917 , r10:  0.35845 , r50:  0.501002 , auc:  0.86602 , count:  26948
# 2021-04-23 04:16:26,798   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 41.32 s ( 0.0026 M/sec ); Eval 2*26948 edges in 2.48 s ( 0.022 M/sec ); io: 0.19 s for 72,408,184 bytes ( 377.55 MB/sec )
# 2021-04-23 04:16:26,802   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:16:26,803   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:16:26,920   [Trainer-0] Finished epoch 59 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:16:26,921   [Trainer-0] Writing the metadata
# 2021-04-23 04:16:26,948   [Trainer-0] Writing the training stats
# 2021-04-23 04:16:26,960   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:16:26,961   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:16:26,965   [Trainer-0] Starting epoch 60 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:16:26,969   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:16:26,971   [Trainer-0] still in queue: 0
# 2021-04-23 04:16:26,972   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:16:26,972   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:16:27,987   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9754 , pos_rank:  241.965 , mrr:  0.262151 , r1:  0.206861 , r10:  0.35793 , r50:  0.500853 , auc:  0.864758 , count:  26948
# 2021-04-23 04:16:47,390   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.13191 , reg:  0.0859743 , violators_lhs:  5.09203 , violators_rhs:  0.105378 , count:  107793
# 2021-04-23 04:16:49,028   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9689 , pos_rank:  241.842 , mrr:  0.262233 , r1:  0.206546 , r10:  0.358412 , r50:  0.501781 , auc:  0.864016 , count:  26948
# 2021-04-23 04:16:49,029   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 19.42 s ( 0.0056 M/sec ); Eval 2*26948 edges in 2.45 s ( 0.022 M/sec ); io: 0.19 s for 72,408,184 bytes ( 388.38 MB/sec )
# 2021-04-23 04:16:49,029   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:16:49,033   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:16:49,072   [Trainer-0] Finished epoch 60 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:16:49,073   [Trainer-0] Writing the metadata
# 2021-04-23 04:16:49,104   [Trainer-0] Writing the training stats
# 2021-04-23 04:16:49,117   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:16:49,117   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:16:49,127   [Trainer-0] Starting epoch 61 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:16:49,132   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:16:49,145   [Trainer-0] still in queue: 0
# 2021-04-23 04:16:49,151   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:16:49,151   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:16:51,332   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9629 , pos_rank:  241.384 , mrr:  0.262393 , r1:  0.206639 , r10:  0.358041 , r50:  0.502152 , auc:  0.863404 , count:  26948
# 2021-04-23 04:17:22,526   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.12849 , reg:  0.0858342 , violators_lhs:  5.07197 , violators_rhs:  0.102483 , count:  107793
# 2021-04-23 04:17:25,760   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9634 , pos_rank:  241.309 , mrr:  0.262525 , r1:  0.206861 , r10:  0.358561 , r50:  0.503173 , auc:  0.86524 , count:  26948
# 2021-04-23 04:17:25,760   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 31.20 s ( 0.0035 M/sec ); Eval 2*26948 edges in 4.67 s ( 0.012 M/sec ); io: 0.74 s for 72,408,184 bytes ( 98.02 MB/sec )
# 2021-04-23 04:17:25,761   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:17:25,761   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:17:25,816   [Trainer-0] Finished epoch 61 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:17:25,817   [Trainer-0] Writing the metadata
# 2021-04-23 04:17:25,833   [Trainer-0] Writing the training stats
# 2021-04-23 04:17:25,839   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:17:25,839   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:17:25,846   [Trainer-0] Starting epoch 62 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:17:25,848   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:17:25,849   [Trainer-0] still in queue: 0
# 2021-04-23 04:17:25,849   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:17:25,850   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:17:27,283   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9584 , pos_rank:  240.962 , mrr:  0.262564 , r1:  0.206731 , r10:  0.35832 , r50:  0.504156 , auc:  0.86782 , count:  26948
# 2021-04-23 04:17:52,453   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.12448 , reg:  0.0856045 , violators_lhs:  5.08378 , violators_rhs:  0.104098 , count:  107793
# 2021-04-23 04:17:54,555   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9607 , pos_rank:  242.305 , mrr:  0.262207 , r1:  0.205952 , r10:  0.359322 , r50:  0.503451 , auc:  0.863459 , count:  26948
# 2021-04-23 04:17:54,558   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 25.18 s ( 0.0043 M/sec ); Eval 2*26948 edges in 3.39 s ( 0.016 M/sec ); io: 0.14 s for 72,408,184 bytes ( 502.65 MB/sec )
# 2021-04-23 04:17:54,559   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:17:54,559   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:17:54,639   [Trainer-0] Finished epoch 62 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:17:54,640   [Trainer-0] Writing the metadata
# 2021-04-23 04:17:54,668   [Trainer-0] Writing the training stats
# 2021-04-23 04:17:54,670   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:17:54,677   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:17:54,693   [Trainer-0] Starting epoch 63 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:17:54,698   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:17:54,698   [Trainer-0] still in queue: 0
# 2021-04-23 04:17:54,700   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:17:54,700   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:17:55,933   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9652 , pos_rank:  240.844 , mrr:  0.262261 , r1:  0.205878 , r10:  0.359767 , r50:  0.503785 , auc:  0.862216 , count:  26948
# 2021-04-23 04:18:16,237   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.12753 , reg:  0.0854454 , violators_lhs:  5.08515 , violators_rhs:  0.103587 , count:  107793
# 2021-04-23 04:18:18,217   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.947 , pos_rank:  241.129 , mrr:  0.263369 , r1:  0.207566 , r10:  0.359897 , r50:  0.503618 , auc:  0.866799 , count:  26948
# 2021-04-23 04:18:18,218   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 20.31 s ( 0.0053 M/sec ); Eval 2*26948 edges in 3.05 s ( 0.018 M/sec ); io: 0.15 s for 72,408,184 bytes ( 473.34 MB/sec )
# 2021-04-23 04:18:18,218   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:18:18,219   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:18:18,294   [Trainer-0] Finished epoch 63 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:18:18,294   [Trainer-0] Writing the metadata
# 2021-04-23 04:18:18,308   [Trainer-0] Writing the training stats
# 2021-04-23 04:18:18,310   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:18:18,310   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:18:18,311   [Trainer-0] Starting epoch 64 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:18:18,312   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:18:18,313   [Trainer-0] still in queue: 0
# 2021-04-23 04:18:18,313   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:18:18,313   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:18:20,364   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9625 , pos_rank:  241.147 , mrr:  0.262713 , r1:  0.206472 , r10:  0.359043 , r50:  0.50334 , auc:  0.86461 , count:  26948
# 2021-04-23 04:18:45,183   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.12412 , reg:  0.0852676 , violators_lhs:  5.05522 , violators_rhs:  0.105665 , count:  107793
# 2021-04-23 04:18:47,330   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9611 , pos_rank:  241.128 , mrr:  0.262851 , r1:  0.206323 , r10:  0.35947 , r50:  0.502598 , auc:  0.868469 , count:  26948
# 2021-04-23 04:18:47,332   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 24.85 s ( 0.0043 M/sec ); Eval 2*26948 edges in 3.33 s ( 0.016 M/sec ); io: 0.84 s for 72,408,184 bytes ( 86.33 MB/sec )
# 2021-04-23 04:18:47,338   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:18:47,339   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:18:47,444   [Trainer-0] Finished epoch 64 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:18:47,445   [Trainer-0] Writing the metadata
# 2021-04-23 04:18:47,458   [Trainer-0] Writing the training stats
# 2021-04-23 04:18:47,460   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:18:47,461   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:18:47,463   [Trainer-0] Starting epoch 65 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:18:47,463   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:18:47,467   [Trainer-0] still in queue: 0
# 2021-04-23 04:18:47,468   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:18:47,468   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:18:48,965   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9582 , pos_rank:  240.821 , mrr:  0.262833 , r1:  0.206564 , r10:  0.359878 , r50:  0.50282 , auc:  0.863478 , count:  26948
# 2021-04-23 04:19:11,362   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.12251 , reg:  0.0851143 , violators_lhs:  5.0547 , violators_rhs:  0.106371 , count:  107793
# 2021-04-23 04:19:13,167   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9611 , pos_rank:  240.966 , mrr:  0.263082 , r1:  0.206954 , r10:  0.359953 , r50:  0.503154 , auc:  0.867022 , count:  26948
# 2021-04-23 04:19:13,170   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 22.43 s ( 0.0048 M/sec ); Eval 2*26948 edges in 2.68 s ( 0.02 M/sec ); io: 0.59 s for 72,408,184 bytes ( 122.15 MB/sec )
# 2021-04-23 04:19:13,170   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:19:13,170   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:19:13,264   [Trainer-0] Finished epoch 65 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:19:13,268   [Trainer-0] Writing the metadata
# 2021-04-23 04:19:13,283   [Trainer-0] Writing the training stats
# 2021-04-23 04:19:13,286   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:19:13,287   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:19:13,293   [Trainer-0] Starting epoch 66 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:19:13,294   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:19:13,298   [Trainer-0] still in queue: 0
# 2021-04-23 04:19:13,298   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:19:13,299   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:19:15,187   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9488 , pos_rank:  240.483 , mrr:  0.262965 , r1:  0.206564 , r10:  0.360249 , r50:  0.503043 , auc:  0.86461 , count:  26948
# 2021-04-23 04:19:41,983   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.12378 , reg:  0.0849923 , violators_lhs:  5.08684 , violators_rhs:  0.105628 , count:  107793
# 2021-04-23 04:19:44,594   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9588 , pos_rank:  240.506 , mrr:  0.263712 , r1:  0.207121 , r10:  0.361251 , r50:  0.503581 , auc:  0.866113 , count:  26948
# 2021-04-23 04:19:44,595   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 26.80 s ( 0.004 M/sec ); Eval 2*26948 edges in 3.82 s ( 0.014 M/sec ); io: 0.68 s for 72,408,184 bytes ( 107.13 MB/sec )
# 2021-04-23 04:19:44,596   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:19:44,597   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:19:44,639   [Trainer-0] Finished epoch 66 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:19:44,640   [Trainer-0] Writing the metadata
# 2021-04-23 04:19:44,667   [Trainer-0] Writing the training stats
# 2021-04-23 04:19:44,672   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:19:44,673   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:19:44,677   [Trainer-0] Starting epoch 67 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:19:44,678   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:19:44,679   [Trainer-0] still in queue: 0
# 2021-04-23 04:19:44,679   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:19:44,680   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:19:45,921   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9315 , pos_rank:  239.407 , mrr:  0.264044 , r1:  0.207288 , r10:  0.361752 , r50:  0.504676 , auc:  0.866094 , count:  26948
# 2021-04-23 04:20:23,265   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.12033 , reg:  0.0848743 , violators_lhs:  5.05136 , violators_rhs:  0.105294 , count:  107793
# 2021-04-23 04:20:25,606   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9262 , pos_rank:  239.983 , mrr:  0.264167 , r1:  0.207529 , r10:  0.361344 , r50:  0.503729 , auc:  0.865519 , count:  26948
# 2021-04-23 04:20:25,607   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 37.35 s ( 0.0029 M/sec ); Eval 2*26948 edges in 3.44 s ( 0.016 M/sec ); io: 0.13 s for 72,408,184 bytes ( 546.26 MB/sec )
# 2021-04-23 04:20:25,613   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:20:25,613   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:20:25,714   [Trainer-0] Finished epoch 67 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:20:25,715   [Trainer-0] Writing the metadata
# 2021-04-23 04:20:25,729   [Trainer-0] Writing the training stats
# 2021-04-23 04:20:25,734   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:20:25,735   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:20:25,737   [Trainer-0] Starting epoch 68 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:20:25,739   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:20:25,740   [Trainer-0] still in queue: 0
# 2021-04-23 04:20:25,740   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:20:25,741   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:20:27,227   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9354 , pos_rank:  240.489 , mrr:  0.264221 , r1:  0.207529 , r10:  0.361511 , r50:  0.503896 , auc:  0.864702 , count:  26948
# 2021-04-23 04:21:59,920   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.12499 , reg:  0.084644 , violators_lhs:  5.0781 , violators_rhs:  0.10496 , count:  107793
# 2021-04-23 04:22:02,667   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9417 , pos_rank:  240.174 , mrr:  0.26421 , r1:  0.207622 , r10:  0.361474 , r50:  0.504527 , auc:  0.864554 , count:  26948
# 2021-04-23 04:22:02,667   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 92.70 s ( 0.0012 M/sec ); Eval 2*26948 edges in 3.77 s ( 0.014 M/sec ); io: 0.46 s for 72,408,184 bytes ( 156.95 MB/sec )
# 2021-04-23 04:22:02,668   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:22:02,669   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:22:02,730   [Trainer-0] Finished epoch 68 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:22:02,730   [Trainer-0] Writing the metadata
# 2021-04-23 04:22:02,742   [Trainer-0] Writing the training stats
# 2021-04-23 04:22:02,746   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:22:02,747   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:22:02,755   [Trainer-0] Starting epoch 69 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:22:02,757   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:22:02,758   [Trainer-0] still in queue: 0
# 2021-04-23 04:22:02,758   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:22:02,759   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:22:04,686   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9323 , pos_rank:  239.989 , mrr:  0.264266 , r1:  0.207808 , r10:  0.36127 , r50:  0.50423 , auc:  0.865445 , count:  26948
# 2021-04-23 04:22:38,742   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.11724 , reg:  0.0844833 , violators_lhs:  5.06741 , violators_rhs:  0.102131 , count:  107793
# 2021-04-23 04:22:41,930   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.949 , pos_rank:  240.65 , mrr:  0.264562 , r1:  0.20868 , r10:  0.361159 , r50:  0.504898 , auc:  0.865445 , count:  26948
# 2021-04-23 04:22:41,931   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 34.07 s ( 0.0032 M/sec ); Eval 2*26948 edges in 4.84 s ( 0.011 M/sec ); io: 0.26 s for 72,408,184 bytes ( 274.07 MB/sec )
# 2021-04-23 04:22:41,932   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:22:41,933   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:22:41,987   [Trainer-0] Finished epoch 69 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:22:41,988   [Trainer-0] Writing the metadata
# 2021-04-23 04:22:42,007   [Trainer-0] Writing the training stats
# 2021-04-23 04:22:42,011   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:22:42,011   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:22:42,021   [Trainer-0] Starting epoch 70 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:22:42,030   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:22:42,031   [Trainer-0] still in queue: 0
# 2021-04-23 04:22:42,031   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:22:42,032   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:22:43,493   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9529 , pos_rank:  240.469 , mrr:  0.264329 , r1:  0.208012 , r10:  0.361307 , r50:  0.504601 , auc:  0.865686 , count:  26948
# 2021-04-23 04:23:30,434   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.12182 , reg:  0.0843631 , violators_lhs:  5.03597 , violators_rhs:  0.10573 , count:  107793
# 2021-04-23 04:23:32,430   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.93 , pos_rank:  240.354 , mrr:  0.264504 , r1:  0.207789 , r10:  0.362476 , r50:  0.504806 , auc:  0.865723 , count:  26948
# 2021-04-23 04:23:32,433   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 46.95 s ( 0.0023 M/sec ); Eval 2*26948 edges in 3.32 s ( 0.016 M/sec ); io: 0.14 s for 72,408,184 bytes ( 536.24 MB/sec )
# 2021-04-23 04:23:32,433   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:23:32,434   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:23:32,524   [Trainer-0] Finished epoch 70 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:23:32,524   [Trainer-0] Writing the metadata
# 2021-04-23 04:23:32,567   [Trainer-0] Writing the training stats
# 2021-04-23 04:23:32,571   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:23:32,572   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:23:32,606   [Trainer-0] Starting epoch 71 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:23:32,607   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:23:32,608   [Trainer-0] still in queue: 0
# 2021-04-23 04:23:32,608   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:23:32,609   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:23:34,286   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9407 , pos_rank:  240.583 , mrr:  0.26424 , r1:  0.207511 , r10:  0.362457 , r50:  0.504676 , auc:  0.865055 , count:  26948
# 2021-04-23 04:24:11,890   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.11884 , reg:  0.0842206 , violators_lhs:  5.04786 , violators_rhs:  0.103541 , count:  107793
# 2021-04-23 04:24:13,956   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9499 , pos_rank:  240.218 , mrr:  0.26401 , r1:  0.206676 , r10:  0.361975 , r50:  0.505214 , auc:  0.863886 , count:  26948
# 2021-04-23 04:24:13,957   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 37.61 s ( 0.0029 M/sec ); Eval 2*26948 edges in 3.31 s ( 0.016 M/sec ); io: 0.43 s for 72,408,184 bytes ( 170.23 MB/sec )
# 2021-04-23 04:24:13,957   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:24:13,958   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:24:14,007   [Trainer-0] Finished epoch 71 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:24:14,007   [Trainer-0] Writing the metadata
# 2021-04-23 04:24:14,032   [Trainer-0] Writing the training stats
# 2021-04-23 04:24:14,038   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:24:14,039   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:24:14,058   [Trainer-0] Starting epoch 72 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:24:14,062   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:24:14,063   [Trainer-0] still in queue: 0
# 2021-04-23 04:24:14,064   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:24:14,064   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:24:15,656   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.917 , pos_rank:  239.703 , mrr:  0.264224 , r1:  0.207344 , r10:  0.362439 , r50:  0.505807 , auc:  0.864814 , count:  26948
# 2021-04-23 04:24:44,731   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.11674 , reg:  0.0840364 , violators_lhs:  5.05563 , violators_rhs:  0.103569 , count:  107793
# 2021-04-23 04:24:46,991   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9198 , pos_rank:  239.469 , mrr:  0.26507 , r1:  0.208494 , r10:  0.363793 , r50:  0.506086 , auc:  0.864832 , count:  26948
# 2021-04-23 04:24:46,994   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 29.08 s ( 0.0037 M/sec ); Eval 2*26948 edges in 3.49 s ( 0.015 M/sec ); io: 0.36 s for 72,408,184 bytes ( 201.12 MB/sec )
# 2021-04-23 04:24:46,997   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:24:46,998   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:24:47,165   [Trainer-0] Finished epoch 72 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:24:47,166   [Trainer-0] Writing the metadata
# 2021-04-23 04:24:47,189   [Trainer-0] Writing the training stats
# 2021-04-23 04:24:47,194   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:24:47,195   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:24:47,204   [Trainer-0] Starting epoch 73 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:24:47,204   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:24:47,213   [Trainer-0] still in queue: 0
# 2021-04-23 04:24:47,214   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:24:47,214   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:24:48,699   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9328 , pos_rank:  239.347 , mrr:  0.264172 , r1:  0.207047 , r10:  0.363775 , r50:  0.506513 , auc:  0.865036 , count:  26948
# 2021-04-23 04:25:21,865   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.11797 , reg:  0.0838967 , violators_lhs:  5.07302 , violators_rhs:  0.101658 , count:  107793
# 2021-04-23 04:25:24,250   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9208 , pos_rank:  239.006 , mrr:  0.264449 , r1:  0.207047 , r10:  0.363199 , r50:  0.506327 , auc:  0.863682 , count:  26948
# 2021-04-23 04:25:24,251   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 33.17 s ( 0.0032 M/sec ); Eval 2*26948 edges in 3.54 s ( 0.015 M/sec ); io: 0.33 s for 72,408,184 bytes ( 220.27 MB/sec )
# 2021-04-23 04:25:24,252   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:25:24,253   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:25:24,336   [Trainer-0] Finished epoch 73 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:25:24,336   [Trainer-0] Writing the metadata
# 2021-04-23 04:25:24,362   [Trainer-0] Writing the training stats
# 2021-04-23 04:25:24,368   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:25:24,368   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:25:24,372   [Trainer-0] Starting epoch 74 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:25:24,373   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:25:24,377   [Trainer-0] still in queue: 0
# 2021-04-23 04:25:24,378   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:25:24,378   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:25:26,425   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9203 , pos_rank:  239.474 , mrr:  0.264861 , r1:  0.20829 , r10:  0.363088 , r50:  0.506438 , auc:  0.86461 , count:  26948
# 2021-04-23 04:26:49,604   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.11472 , reg:  0.0837515 , violators_lhs:  5.05655 , violators_rhs:  0.103393 , count:  107793
# 2021-04-23 04:26:51,386   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9283 , pos_rank:  239.503 , mrr:  0.265102 , r1:  0.20816 , r10:  0.364034 , r50:  0.506086 , auc:  0.863441 , count:  26948
# 2021-04-23 04:26:51,391   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 83.17 s ( 0.0013 M/sec ); Eval 2*26948 edges in 3.13 s ( 0.017 M/sec ); io: 0.68 s for 72,408,184 bytes ( 107.07 MB/sec )
# 2021-04-23 04:26:51,394   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:26:51,396   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:26:51,940   [Trainer-0] Finished epoch 74 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:26:51,940   [Trainer-0] Writing the metadata
# 2021-04-23 04:26:52,028   [Trainer-0] Writing the training stats
# 2021-04-23 04:26:52,054   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:26:52,055   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:26:52,061   [Trainer-0] Starting epoch 75 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:26:52,068   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:26:52,075   [Trainer-0] still in queue: 0
# 2021-04-23 04:26:52,076   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:26:52,076   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:44:25,801   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9189 , pos_rank:  239.189 , mrr:  0.265435 , r1:  0.208791 , r10:  0.364665 , r50:  0.506587 , auc:  0.867152 , count:  26948
# 2021-04-23 04:55:28,826   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.11704 , reg:  0.0835938 , violators_lhs:  5.05088 , violators_rhs:  0.102057 , count:  107793
# 2021-04-23 04:55:31,885   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9187 , pos_rank:  239.316 , mrr:  0.266106 , r1:  0.209329 , r10:  0.365129 , r50:  0.505678 , auc:  0.866502 , count:  26948
# 2021-04-23 04:55:31,887   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 317.47 s ( 0.00034 M/sec ); Eval 2*26948 edges in 5.85 s ( 0.0092 M/sec ); io: 0.75 s for 72,408,184 bytes ( 96.75 MB/sec )
# 2021-04-23 04:55:31,888   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:55:31,889   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:55:32,636   [Trainer-0] Finished epoch 75 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:55:32,638   [Trainer-0] Writing the metadata
# 2021-04-23 04:55:32,677   [Trainer-0] Writing the training stats
# 2021-04-23 04:55:32,762   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:55:32,763   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:55:32,765   [Trainer-0] Starting epoch 76 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:55:32,767   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:55:32,768   [Trainer-0] still in queue: 0
# 2021-04-23 04:55:32,769   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:55:32,769   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:55:35,139   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9149 , pos_rank:  239.528 , mrr:  0.265307 , r1:  0.208086 , r10:  0.365092 , r50:  0.505436 , auc:  0.864517 , count:  26948
# 2021-04-23 04:56:07,998   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.1118 , reg:  0.083473 , violators_lhs:  5.04573 , violators_rhs:  0.103356 , count:  107793
# 2021-04-23 04:56:10,657   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9039 , pos_rank:  238.819 , mrr:  0.265379 , r1:  0.20855 , r10:  0.363552 , r50:  0.50629 , auc:  0.86871 , count:  26948
# 2021-04-23 04:56:10,657   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 32.86 s ( 0.0033 M/sec ); Eval 2*26948 edges in 4.63 s ( 0.012 M/sec ); io: 0.40 s for 72,408,184 bytes ( 179.56 MB/sec )
# 2021-04-23 04:56:10,658   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:56:10,659   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:56:10,731   [Trainer-0] Finished epoch 76 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:56:10,731   [Trainer-0] Writing the metadata
# 2021-04-23 04:56:10,769   [Trainer-0] Writing the training stats
# 2021-04-23 04:56:10,771   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:56:10,771   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:56:10,774   [Trainer-0] Starting epoch 77 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:56:10,776   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:56:10,776   [Trainer-0] still in queue: 0
# 2021-04-23 04:56:10,777   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:56:10,777   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:56:12,597   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9051 , pos_rank:  239.227 , mrr:  0.26566 , r1:  0.209106 , r10:  0.363385 , r50:  0.506234 , auc:  0.8655 , count:  26948
# 2021-04-23 04:56:39,650   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.11572 , reg:  0.0833403 , violators_lhs:  5.0496 , violators_rhs:  0.10355 , count:  107793
# 2021-04-23 04:56:41,772   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9088 , pos_rank:  238.91 , mrr:  0.265378 , r1:  0.208457 , r10:  0.364109 , r50:  0.507663 , auc:  0.865073 , count:  26948
# 2021-04-23 04:56:41,773   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 27.06 s ( 0.004 M/sec ); Eval 2*26948 edges in 3.54 s ( 0.015 M/sec ); io: 0.40 s for 72,408,184 bytes ( 180.55 MB/sec )
# 2021-04-23 04:56:41,774   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 04:56:41,774   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 04:56:41,820   [Trainer-0] Finished epoch 77 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:56:41,820   [Trainer-0] Writing the metadata
# 2021-04-23 04:56:41,840   [Trainer-0] Writing the training stats
# 2021-04-23 04:56:41,843   [Trainer-0] Writing the checkpoint
# 2021-04-23 04:56:41,844   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 04:56:41,848   [Trainer-0] Starting epoch 78 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 04:56:41,855   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 04:56:41,856   [Trainer-0] still in queue: 0
# 2021-04-23 04:56:41,856   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 04:56:41,857   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 04:56:43,117   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9078 , pos_rank:  238.89 , mrr:  0.265576 , r1:  0.208327 , r10:  0.363793 , r50:  0.507329 , auc:  0.86383 , count:  26948
# 2021-04-23 05:32:59,449   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.11311 , reg:  0.0831619 , violators_lhs:  5.05164 , violators_rhs:  0.103773 , count:  107793
# 2021-04-23 05:33:02,176   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.8845 , pos_rank:  239.06 , mrr:  0.267027 , r1:  0.209774 , r10:  0.36537 , r50:  0.506568 , auc:  0.864461 , count:  26948
# 2021-04-23 05:33:02,176   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 45.83 s ( 0.0024 M/sec ); Eval 2*26948 edges in 3.60 s ( 0.015 M/sec ); io: 0.35 s for 72,408,184 bytes ( 209.24 MB/sec )
# 2021-04-23 05:33:02,177   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 05:33:02,178   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 05:33:02,347   [Trainer-0] Finished epoch 78 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 05:33:02,347   [Trainer-0] Writing the metadata
# 2021-04-23 05:33:02,361   [Trainer-0] Writing the training stats
# 2021-04-23 05:33:02,379   [Trainer-0] Writing the checkpoint
# 2021-04-23 05:33:02,380   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 05:33:02,384   [Trainer-0] Starting epoch 79 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 05:33:02,386   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 05:33:02,387   [Trainer-0] still in queue: 0
# 2021-04-23 05:33:02,387   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 05:33:02,388   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 05:33:03,856   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.8952 , pos_rank:  238.965 , mrr:  0.267367 , r1:  0.211166 , r10:  0.364888 , r50:  0.506475 , auc:  0.865278 , count:  26948
# 2021-04-23 06:42:56,574   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.11038 , reg:  0.0830794 , violators_lhs:  5.01287 , violators_rhs:  0.103272 , count:  107793
# 2021-04-23 06:42:57,838   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9041 , pos_rank:  238.864 , mrr:  0.266631 , r1:  0.210183 , r10:  0.36524 , r50:  0.506513 , auc:  0.865073 , count:  26948
# 2021-04-23 06:42:57,842   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 46.07 s ( 0.0023 M/sec ); Eval 2*26948 edges in 2.20 s ( 0.024 M/sec ); io: 0.50 s for 72,408,184 bytes ( 144.46 MB/sec )
# 2021-04-23 06:42:57,843   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 06:42:57,845   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 06:42:58,032   [Trainer-0] Finished epoch 79 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 06:42:58,032   [Trainer-0] Writing the metadata
# 2021-04-23 06:42:58,061   [Trainer-0] Writing the training stats
# 2021-04-23 06:42:58,073   [Trainer-0] Writing the checkpoint
# 2021-04-23 06:42:58,074   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 06:42:58,077   [Trainer-0] Starting epoch 80 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 06:42:58,087   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 06:42:58,089   [Trainer-0] still in queue: 0
# 2021-04-23 06:42:58,090   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 06:42:58,090   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 06:42:58,996   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9132 , pos_rank:  238.47 , mrr:  0.265911 , r1:  0.209051 , r10:  0.365407 , r50:  0.506179 , auc:  0.864851 , count:  26948
# 2021-04-23 08:04:13,976   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.1115 , reg:  0.0829263 , violators_lhs:  5.0238 , violators_rhs:  0.103272 , count:  107793
# 2021-04-23 08:04:16,319   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.889 , pos_rank:  238.612 , mrr:  0.266507 , r1:  0.209218 , r10:  0.366261 , r50:  0.507366 , auc:  0.865964 , count:  26948
# 2021-04-23 08:04:16,322   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 41.59 s ( 0.0026 M/sec ); Eval 2*26948 edges in 3.15 s ( 0.017 M/sec ); io: 0.07 s for 72,408,184 bytes ( 988.28 MB/sec )
# 2021-04-23 08:04:16,322   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 08:04:16,323   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 08:04:16,621   [Trainer-0] Finished epoch 80 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 08:04:16,621   [Trainer-0] Writing the metadata
# 2021-04-23 08:04:16,631   [Trainer-0] Writing the training stats
# 2021-04-23 08:04:16,644   [Trainer-0] Writing the checkpoint
# 2021-04-23 08:04:16,645   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 08:04:16,648   [Trainer-0] Starting epoch 81 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 08:04:16,650   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 08:04:16,651   [Trainer-0] still in queue: 0
# 2021-04-23 08:04:16,651   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 08:04:16,652   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 08:04:18,238   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.8987 , pos_rank:  238.373 , mrr:  0.266371 , r1:  0.209106 , r10:  0.366261 , r50:  0.506921 , auc:  0.86717 , count:  26948
# 2021-04-23 08:04:55,851   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.10944 , reg:  0.082762 , violators_lhs:  5.03125 , violators_rhs:  0.102984 , count:  107793
# 2021-04-23 08:04:57,681   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.8845 , pos_rank:  238.294 , mrr:  0.265827 , r1:  0.208012 , r10:  0.365222 , r50:  0.507756 , auc:  0.865092 , count:  26948
# 2021-04-23 08:04:57,682   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 37.63 s ( 0.0029 M/sec ); Eval 2*26948 edges in 3.00 s ( 0.018 M/sec ); io: 0.41 s for 72,408,184 bytes ( 176.36 MB/sec )
# 2021-04-23 08:04:57,683   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 08:04:57,684   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 08:04:57,827   [Trainer-0] Finished epoch 81 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 08:04:57,827   [Trainer-0] Writing the metadata
# 2021-04-23 08:04:57,864   [Trainer-0] Writing the training stats
# 2021-04-23 08:04:57,869   [Trainer-0] Writing the checkpoint
# 2021-04-23 08:04:57,870   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 08:04:57,880   [Trainer-0] Starting epoch 82 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 08:04:57,891   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 08:04:57,900   [Trainer-0] still in queue: 0
# 2021-04-23 08:04:57,901   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 08:04:57,902   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 08:04:59,938   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9067 , pos_rank:  238.843 , mrr:  0.265547 , r1:  0.207938 , r10:  0.36537 , r50:  0.507422 , auc:  0.863645 , count:  26948
# 2021-04-23 08:05:21,565   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.10881 , reg:  0.0826812 , violators_lhs:  5.04785 , violators_rhs:  0.102623 , count:  107793
# 2021-04-23 08:05:22,846   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.8983 , pos_rank:  238.75 , mrr:  0.266786 , r1:  0.209626 , r10:  0.365983 , r50:  0.507477 , auc:  0.865574 , count:  26948
# 2021-04-23 08:05:22,847   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 21.63 s ( 0.005 M/sec ); Eval 2*26948 edges in 2.56 s ( 0.021 M/sec ); io: 0.76 s for 72,408,184 bytes ( 95.61 MB/sec )
# 2021-04-23 08:05:22,848   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 08:05:22,848   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 08:05:23,033   [Trainer-0] Finished epoch 82 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 08:05:23,034   [Trainer-0] Writing the metadata
# 2021-04-23 08:05:23,070   [Trainer-0] Writing the training stats
# 2021-04-23 08:05:23,074   [Trainer-0] Writing the checkpoint
# 2021-04-23 08:05:23,074   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 08:05:23,076   [Trainer-0] Starting epoch 83 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 08:05:23,077   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 08:05:23,085   [Trainer-0] still in queue: 0
# 2021-04-23 08:05:23,086   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 08:05:23,086   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 08:05:24,651   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.8977 , pos_rank:  238.798 , mrr:  0.267082 , r1:  0.210442 , r10:  0.366038 , r50:  0.507366 , auc:  0.86524 , count:  26948
# 2021-04-23 08:05:42,877   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.11137 , reg:  0.0825936 , violators_lhs:  5.02372 , violators_rhs:  0.105007 , count:  107793
# 2021-04-23 08:05:44,367   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9072 , pos_rank:  238.305 , mrr:  0.266691 , r1:  0.209255 , r10:  0.365482 , r50:  0.507459 , auc:  0.866706 , count:  26948
# 2021-04-23 08:05:44,367   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 18.25 s ( 0.0059 M/sec ); Eval 2*26948 edges in 2.44 s ( 0.022 M/sec ); io: 0.59 s for 72,408,184 bytes ( 122.54 MB/sec )
# 2021-04-23 08:05:44,368   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 08:05:44,368   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 08:05:44,476   [Trainer-0] Finished epoch 83 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 08:05:44,477   [Trainer-0] Writing the metadata
# 2021-04-23 08:05:44,506   [Trainer-0] Writing the training stats
# 2021-04-23 08:05:44,510   [Trainer-0] Writing the checkpoint
# 2021-04-23 08:05:44,510   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 08:05:44,533   [Trainer-0] Starting epoch 84 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 08:05:44,536   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 08:05:44,542   [Trainer-0] still in queue: 0
# 2021-04-23 08:05:44,543   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 08:05:44,543   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 08:05:45,658   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.8853 , pos_rank:  238.196 , mrr:  0.266573 , r1:  0.209106 , r10:  0.36589 , r50:  0.507793 , auc:  0.868209 , count:  26948
# 2021-04-23 08:06:02,276   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.10873 , reg:  0.0824788 , violators_lhs:  5.03515 , violators_rhs:  0.0997004 , count:  107793
# 2021-04-23 08:06:03,684   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.9028 , pos_rank:  238.71 , mrr:  0.26687 , r1:  0.20944 , r10:  0.364739 , r50:  0.508145 , auc:  0.864331 , count:  26948
# 2021-04-23 08:06:03,685   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 16.74 s ( 0.0064 M/sec ); Eval 2*26948 edges in 2.14 s ( 0.025 M/sec ); io: 0.27 s for 72,408,184 bytes ( 271.18 MB/sec )
# 2021-04-23 08:06:03,686   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 08:06:03,686   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 08:06:03,853   [Trainer-0] Finished epoch 84 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 08:06:03,854   [Trainer-0] Writing the metadata
# 2021-04-23 08:06:03,877   [Trainer-0] Writing the training stats
# 2021-04-23 08:06:03,882   [Trainer-0] Writing the checkpoint
# 2021-04-23 08:06:03,883   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 08:06:03,909   [Trainer-0] Starting epoch 85 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 08:06:03,913   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 08:06:03,914   [Trainer-0] still in queue: 0
# 2021-04-23 08:06:03,915   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 08:06:03,915   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 08:06:04,935   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.9092 , pos_rank:  238.749 , mrr:  0.266961 , r1:  0.209515 , r10:  0.365574 , r50:  0.508257 , auc:  0.865315 , count:  26948
# 2021-04-23 08:06:27,829   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.10763 , reg:  0.0823926 , violators_lhs:  5.0254 , violators_rhs:  0.104153 , count:  107793
# 2021-04-23 08:06:29,437   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.8927 , pos_rank:  238.605 , mrr:  0.268361 , r1:  0.211314 , r10:  0.366725 , r50:  0.507663 , auc:  0.862439 , count:  26948
# 2021-04-23 08:06:29,438   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 22.91 s ( 0.0047 M/sec ); Eval 2*26948 edges in 2.54 s ( 0.021 M/sec ); io: 0.07 s for 72,408,184 bytes ( 970.23 MB/sec )
# 2021-04-23 08:06:29,438   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 08:06:29,438   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 08:06:29,474   [Trainer-0] Finished epoch 85 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 08:06:29,474   [Trainer-0] Writing the metadata
# ...
# 2021-04-23 14:26:09,454   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 14:26:09,506   [Trainer-0] Finished epoch 191 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:26:09,507   [Trainer-0] Writing the metadata
# 2021-04-23 14:26:09,517   [Trainer-0] Writing the training stats
# 2021-04-23 14:26:09,519   [Trainer-0] Writing the checkpoint
# 2021-04-23 14:26:09,519   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 14:26:09,534   [Trainer-0] Starting epoch 192 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:26:09,535   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 14:26:09,536   [Trainer-0] still in queue: 0
# 2021-04-23 14:26:09,536   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 14:26:09,536   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 14:26:10,404   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.7003 , pos_rank:  231.817 , mrr:  0.276211 , r1:  0.215953 , r10:  0.381067 , r50:  0.524306 , auc:  0.86461 , count:  26948
# 2021-04-23 14:26:24,012   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.07019 , reg:  0.0746753 , violators_lhs:  4.89447 , violators_rhs:  0.0999508 , count:  107793
# 2021-04-23 14:26:24,908   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.7175 , pos_rank:  231.868 , mrr:  0.275076 , r1:  0.214116 , r10:  0.382904 , r50:  0.52477 , auc:  0.868172 , count:  26948
# 2021-04-23 14:26:24,909   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 13.61 s ( 0.0079 M/sec ); Eval 2*26948 edges in 1.73 s ( 0.031 M/sec ); io: 0.03 s for 72,408,184 bytes ( 2592.41 MB/sec )
# 2021-04-23 14:26:24,909   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 14:26:24,910   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 14:26:24,990   [Trainer-0] Finished epoch 192 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:26:24,990   [Trainer-0] Writing the metadata
# 2021-04-23 14:26:24,998   [Trainer-0] Writing the training stats
# 2021-04-23 14:26:25,000   [Trainer-0] Writing the checkpoint
# 2021-04-23 14:26:25,000   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 14:26:25,003   [Trainer-0] Starting epoch 193 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:26:25,004   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 14:26:25,005   [Trainer-0] still in queue: 0
# 2021-04-23 14:26:25,005   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 14:26:25,005   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 14:26:26,121   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.7047 , pos_rank:  232.714 , mrr:  0.275579 , r1:  0.214877 , r10:  0.383034 , r50:  0.524659 , auc:  0.868617 , count:  26948
# 2021-04-23 14:26:37,057   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.07227 , reg:  0.074623 , violators_lhs:  4.90408 , violators_rhs:  0.101732 , count:  107793
# 2021-04-23 14:26:37,991   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.7111 , pos_rank:  232.735 , mrr:  0.275107 , r1:  0.214598 , r10:  0.381271 , r50:  0.524714 , auc:  0.865259 , count:  26948
# 2021-04-23 14:26:37,991   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 10.95 s ( 0.0098 M/sec ); Eval 2*26948 edges in 1.76 s ( 0.031 M/sec ); io: 0.28 s for 72,408,184 bytes ( 257.14 MB/sec )
# 2021-04-23 14:26:37,992   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 14:26:37,993   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 14:26:38,118   [Trainer-0] Finished epoch 193 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:26:38,118   [Trainer-0] Writing the metadata
# 2021-04-23 14:26:38,131   [Trainer-0] Writing the training stats
# 2021-04-23 14:26:38,134   [Trainer-0] Writing the checkpoint
# 2021-04-23 14:26:38,136   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 14:26:38,149   [Trainer-0] Starting epoch 194 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:26:38,150   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 14:26:38,151   [Trainer-0] still in queue: 0
# 2021-04-23 14:26:38,152   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 14:26:38,152   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 14:26:39,000   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.7162 , pos_rank:  232.192 , mrr:  0.275065 , r1:  0.214394 , r10:  0.381383 , r50:  0.525122 , auc:  0.86832 , count:  26948
# 2021-04-23 14:26:51,084   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.07069 , reg:  0.0745365 , violators_lhs:  4.89926 , violators_rhs:  0.0994777 , count:  107793
# 2021-04-23 14:26:51,942   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.709 , pos_rank:  232.126 , mrr:  0.275856 , r1:  0.215285 , r10:  0.381698 , r50:  0.525011 , auc:  0.868005 , count:  26948
# 2021-04-23 14:26:51,943   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 12.09 s ( 0.0089 M/sec ); Eval 2*26948 edges in 1.67 s ( 0.032 M/sec ); io: 0.03 s for 72,408,184 bytes ( 2128.32 MB/sec )
# 2021-04-23 14:26:51,943   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 14:26:51,944   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 14:26:52,002   [Trainer-0] Finished epoch 194 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:26:52,003   [Trainer-0] Writing the metadata
# 2021-04-23 14:26:52,019   [Trainer-0] Writing the training stats
# 2021-04-23 14:26:52,021   [Trainer-0] Writing the checkpoint
# 2021-04-23 14:26:52,021   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 14:26:52,024   [Trainer-0] Starting epoch 195 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:26:52,026   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 14:26:52,027   [Trainer-0] still in queue: 0
# 2021-04-23 14:26:52,027   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 14:26:52,027   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 14:26:52,798   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.7185 , pos_rank:  232.335 , mrr:  0.275716 , r1:  0.215081 , r10:  0.381587 , r50:  0.524955 , auc:  0.866521 , count:  26948
# 2021-04-23 14:27:03,466   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.0692 , reg:  0.0745069 , violators_lhs:  4.89479 , violators_rhs:  0.100786 , count:  107793
# 2021-04-23 14:27:04,432   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.708 , pos_rank:  231.617 , mrr:  0.274926 , r1:  0.214339 , r10:  0.381884 , r50:  0.524621 , auc:  0.866391 , count:  26948
# 2021-04-23 14:27:04,433   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 10.67 s ( 0.01 M/sec ); Eval 2*26948 edges in 1.72 s ( 0.031 M/sec ); io: 0.02 s for 72,408,184 bytes ( 4577.56 MB/sec )
# 2021-04-23 14:27:04,434   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 14:27:04,434   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 14:27:04,492   [Trainer-0] Finished epoch 195 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:27:04,492   [Trainer-0] Writing the metadata
# 2021-04-23 14:27:04,499   [Trainer-0] Writing the training stats
# 2021-04-23 14:27:04,501   [Trainer-0] Writing the checkpoint
# 2021-04-23 14:27:04,501   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 14:27:04,505   [Trainer-0] Starting epoch 196 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:27:04,507   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 14:27:04,507   [Trainer-0] still in queue: 0
# 2021-04-23 14:27:04,508   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 14:27:04,508   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 14:27:05,577   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.7169 , pos_rank:  232.311 , mrr:  0.275075 , r1:  0.214413 , r10:  0.38168 , r50:  0.524343 , auc:  0.8673 , count:  26948
# 2021-04-23 14:27:16,828   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.06886 , reg:  0.074508 , violators_lhs:  4.91532 , violators_rhs:  0.101723 , count:  107793
# 2021-04-23 14:27:17,665   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.7078 , pos_rank:  231.559 , mrr:  0.276259 , r1:  0.215452 , r10:  0.383442 , r50:  0.524417 , auc:  0.868153 , count:  26948
# 2021-04-23 14:27:17,666   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 11.28 s ( 0.0096 M/sec ); Eval 2*26948 edges in 1.59 s ( 0.034 M/sec ); io: 0.29 s for 72,408,184 bytes ( 248.40 MB/sec )
# 2021-04-23 14:27:17,668   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 14:27:17,669   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 14:27:17,725   [Trainer-0] Finished epoch 196 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:27:17,726   [Trainer-0] Writing the metadata
# 2021-04-23 14:27:17,733   [Trainer-0] Writing the training stats
# 2021-04-23 14:27:17,735   [Trainer-0] Writing the checkpoint
# 2021-04-23 14:27:17,735   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 14:27:17,737   [Trainer-0] Starting epoch 197 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:27:17,738   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 14:27:17,739   [Trainer-0] still in queue: 0
# 2021-04-23 14:27:17,739   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 14:27:17,739   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 14:27:19,010   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.6993 , pos_rank:  231.493 , mrr:  0.276328 , r1:  0.215229 , r10:  0.383535 , r50:  0.5249 , auc:  0.869155 , count:  26948
# 2021-04-23 14:27:29,922   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.06781 , reg:  0.0744099 , violators_lhs:  4.87774 , violators_rhs:  0.10112 , count:  107793
# 2021-04-23 14:27:30,807   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.7079 , pos_rank:  231.631 , mrr:  0.276135 , r1:  0.214654 , r10:  0.383479 , r50:  0.524974 , auc:  0.867671 , count:  26948
# 2021-04-23 14:27:30,807   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 10.96 s ( 0.0098 M/sec ); Eval 2*26948 edges in 1.80 s ( 0.03 M/sec ); io: 0.30 s for 72,408,184 bytes ( 239.02 MB/sec )
# 2021-04-23 14:27:30,808   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 14:27:30,808   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 14:27:30,873   [Trainer-0] Finished epoch 197 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:27:30,873   [Trainer-0] Writing the metadata
# 2021-04-23 14:27:30,884   [Trainer-0] Writing the training stats
# 2021-04-23 14:27:30,886   [Trainer-0] Writing the checkpoint
# 2021-04-23 14:27:30,886   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 14:27:30,891   [Trainer-0] Starting epoch 198 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:27:30,893   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 14:27:30,893   [Trainer-0] still in queue: 0
# 2021-04-23 14:27:30,895   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 14:27:30,895   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 14:27:31,831   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.7015 , pos_rank:  231.71 , mrr:  0.276488 , r1:  0.215025 , r10:  0.384017 , r50:  0.524955 , auc:  0.865946 , count:  26948
# 2021-04-23 14:27:42,578   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.06913 , reg:  0.0743293 , violators_lhs:  4.87578 , violators_rhs:  0.10137 , count:  107793
# 2021-04-23 14:27:43,482   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.7039 , pos_rank:  232.107 , mrr:  0.27604 , r1:  0.214728 , r10:  0.384092 , r50:  0.524918 , auc:  0.86923 , count:  26948
# 2021-04-23 14:27:43,483   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 10.76 s ( 0.01 M/sec ); Eval 2*26948 edges in 1.66 s ( 0.032 M/sec ); io: 0.17 s for 72,408,184 bytes ( 417.38 MB/sec )
# 2021-04-23 14:27:43,483   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 14:27:43,484   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 14:27:43,539   [Trainer-0] Finished epoch 198 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:27:43,540   [Trainer-0] Writing the metadata
# 2021-04-23 14:27:43,552   [Trainer-0] Writing the training stats
# 2021-04-23 14:27:43,554   [Trainer-0] Writing the checkpoint
# 2021-04-23 14:27:43,554   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 14:27:43,559   [Trainer-0] Starting epoch 199 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:27:43,560   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 14:27:43,560   [Trainer-0] still in queue: 0
# 2021-04-23 14:27:43,561   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 14:27:43,561   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 14:27:44,545   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.682 , pos_rank:  230.817 , mrr:  0.276864 , r1:  0.215823 , r10:  0.384314 , r50:  0.525531 , auc:  0.868469 , count:  26948
# 2021-04-23 14:28:01,163   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.06802 , reg:  0.0743563 , violators_lhs:  4.89574 , violators_rhs:  0.100248 , count:  107793
# 2021-04-23 14:28:02,128   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.7012 , pos_rank:  232.015 , mrr:  0.276629 , r1:  0.215693 , r10:  0.383053 , r50:  0.52451 , auc:  0.867727 , count:  26948
# 2021-04-23 14:28:02,130   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 16.62 s ( 0.0065 M/sec ); Eval 2*26948 edges in 1.81 s ( 0.03 M/sec ); io: 0.14 s for 72,408,184 bytes ( 514.61 MB/sec )
# 2021-04-23 14:28:02,133   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 14:28:02,133   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 14:28:02,176   [Trainer-0] Finished epoch 199 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:28:02,177   [Trainer-0] Writing the metadata
# 2021-04-23 14:28:02,192   [Trainer-0] Writing the training stats
# 2021-04-23 14:28:02,198   [Trainer-0] Writing the checkpoint
# 2021-04-23 14:28:02,199   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 14:28:02,203   [Trainer-0] Starting epoch 200 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:28:02,205   [Trainer-0] Edge path: data/example_2/edge_path
# 2021-04-23 14:28:02,205   [Trainer-0] still in queue: 0
# 2021-04-23 14:28:02,206   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-23 14:28:02,206   [Trainer-0] Loading partitioned embeddings from checkpoint
# 2021-04-23 14:28:03,188   [Trainer-0] ( 0 , 0 ): Stats before training: loss:  12.7081 , pos_rank:  231.648 , mrr:  0.276423 , r1:  0.215489 , r10:  0.38283 , r50:  0.524455 , auc:  0.870009 , count:  26948
# 2021-04-23 14:28:16,944   [Trainer-0] ( 0 , 0 ): Training stats: loss:  1.06624 , reg:  0.0743765 , violators_lhs:  4.88457 , violators_rhs:  0.0979284 , count:  107793
# 2021-04-23 14:28:17,950   [Trainer-0] ( 0 , 0 ): Stats after training: loss:  12.6977 , pos_rank:  231.981 , mrr:  0.276171 , r1:  0.215007 , r10:  0.383479 , r50:  0.524714 , auc:  0.868116 , count:  26948
# 2021-04-23 14:28:17,954   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Trained 107793 edges in 13.76 s ( 0.0078 M/sec ); Eval 2*26948 edges in 1.85 s ( 0.029 M/sec ); io: 0.14 s for 72,408,184 bytes ( 525.20 MB/sec )
# 2021-04-23 14:28:17,957   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-23 14:28:17,958   [Trainer-0] Saving partitioned embeddings to checkpoint
# 2021-04-23 14:28:18,014   [Trainer-0] Finished epoch 200 / 200, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-23 14:28:18,015   [Trainer-0] Writing the metadata
# 2021-04-23 14:28:18,028   [Trainer-0] Writing the training stats
# 2021-04-23 14:28:18,030   [Trainer-0] Writing the checkpoint
# 2021-04-23 14:28:18,030   [Trainer-0] Switching to the new checkpoint version
# 2021-04-23 14:28:20,668   [Trainer-0] Exiting

# %%
with open('/Users/BrandenKang/Documents/GitHub/MetaQA_PBG/data/example_2/entity_names_all_0.json', 'r') as f:
    embeddings = json.load(f)

with h5py.File('/Users/BrandenKang/Documents/GitHub/MetaQA_PBG/model_2/embeddings_all_0.v200.h5', 'r') as g:
    embeddings_all = g['embeddings'][:]


embedding_final = dict(zip(embeddings, embeddings_all))

# %%
g = h5py.File('/Users/BrandenKang/Documents/GitHub/MetaQA_PBG/model_2/model.v200.h5', 'r')

# %%
relations_right = g['model/relations/0/operator/rhs/translations']
relations_left = g['model/relations/0/operator/lhs/translations']

# %%
relations_left[:]
# Out:
# array([[ 0.21865478,  0.2853011 ,  0.40159422, ..., -0.18174824,
#          0.32732677, -0.48502034],
#        [ 0.20991768,  0.14671926, -0.11882235, ...,  0.01309311,
#         -0.25235838, -0.37653735],
#        [-0.22295736, -0.30349153,  0.23949671, ..., -0.01469261,
#          0.06565962, -0.40226698],
#        ...,
#        [-0.22331543,  0.05603404,  0.23919353, ...,  0.07602038,
#          0.2768275 ,  0.01640979],
#        [ 0.15918684,  0.13382927,  0.49134213, ..., -0.19542223,
#          0.37968215, -0.381331  ],
#        [ 0.20051032, -0.20698321, -0.24790175, ..., -0.26041842,
#          0.3686345 , -0.3074067 ]], dtype=float32)

# %%
relations_right[:]
# Out:
# array([[-0.36259192, -0.40803045, -0.37224847, ...,  0.35986212,
#         -0.44627145,  0.25324315],
#        [-0.16606267, -0.21822801,  0.21862061, ...,  0.2941766 ,
#          0.15934151,  0.21034053],
#        [ 0.21650203,  0.2897291 , -0.01735711, ...,  0.2929325 ,
#         -0.32193038,  0.39104363],
#        ...,
#        [ 0.24814905, -0.07195609, -0.12324741, ...,  0.26344427,
#         -0.44739208, -0.21042469],
#        [-0.12393223, -0.15010113, -0.57044804, ...,  0.5273425 ,
#         -0.649543  ,  0.20126788],
#        [-0.18542968,  0.20435613,  0.407901  , ...,  0.5385136 ,
#         -0.5753108 ,  0.16237676]], dtype=float32)

# %%
print(embedding_final['Pal_Joey'])

list_1 = list(embedding_final.keys())
list_2 = list(embedding_final.values())
# Out:
# [ 0.51033103  0.03036635  0.06283304  0.35039482  0.14102378 -0.15584126
#  -0.06909858  0.10056009 -0.12430669  0.57119495  0.24161927  0.08698756
#  -0.19983537 -0.03320712 -0.25272903 -0.06555367 -0.27897155 -0.16131715
#   0.1018642   0.09884441  0.07321175 -0.3045629   0.74419653 -0.36212048
#   0.09532339 -0.3320424  -0.02525772  0.6417993  -0.22214678 -0.0059488
#   0.27548715  0.23557724 -0.3091223  -0.12691845  0.2147052  -0.53641385
#  -0.46322057  0.253377   -0.4845521  -0.41634384 -0.20695981  0.04110157
#   0.01109679  0.5099484  -0.08906671  0.5244997   0.39698082 -0.02457639
#  -0.22796789 -0.11731027 -0.05871784 -0.11460497  0.01404705 -0.1718606
#  -0.01661239 -0.17754222 -0.4564989   0.08827218  0.10100427 -0.15504368
#   0.5811918  -0.5132884  -0.24936116 -0.2897802  -0.02560045  0.0054861
#  -0.2521472  -0.11304791  0.15137357 -0.09851966 -0.01950661  0.25187594
#   0.3523791  -0.68075633 -0.12788388  0.10080092 -0.07855184  0.06619365
#  -0.3103227   0.16740805  0.3893558   0.39888203  0.26311892  0.32132977
#  -0.1492614   0.24696025  0.08549178 -0.20024447 -0.06574692  0.2197303
#  -0.10117853 -0.4055489   0.108917   -0.36181477  0.50369567 -0.26460674
#   0.42216188 -0.19579229 -0.08152919  0.25437787 -0.2036379   0.42390344
#   0.00217036 -0.2728822   0.31910467  0.11764768 -0.04417115 -0.0112955
#  -0.42953467  0.2399167  -0.07638405 -0.6852177  -0.2116736  -0.27463517
#  -0.28141043  0.21963227 -0.42677274  0.13497858  0.01532804  0.10868274
#   0.00438895  0.02961785  0.01431181  0.34416127  0.14125766 -0.34049708
#  -0.35620475  0.00106095  0.2309939   0.42748886 -0.22939602  0.4293516
#  -0.14256182  0.15147091  0.48288095  0.09884542  0.01594286 -0.1110273
#   0.22066686  0.07424994  0.14505713  0.10913578 -0.35889238  0.40045002
#  -0.12766708  0.16419216 -0.26993376 -0.03311832  0.26795864 -0.19704026
#  -0.22336283  0.0041164  -0.2956184  -0.00799398  0.0189838  -0.1026849
#   0.09394602 -0.03101834 -0.04716682 -0.460347    0.07481664  0.22544934
#   0.34404668 -0.09076067 -0.25428963 -0.28007707  0.2473733  -0.13416125
#  -0.595611   -0.21366468 -0.1427123  -0.3217544   0.26773262  0.10166379
#   0.0049473   0.45549056 -0.8406017  -0.09755637  0.41132623 -0.14277564
#  -0.41779128  0.00090904 -0.1600984  -0.21727109 -0.20814373  0.43857476
#  -0.12584832 -0.16353151 -0.02669609  0.31932956 -0.25711757 -0.14807314
#   0.2603154   0.14166343  0.13258052 -0.2662763   0.29742706 -0.1319753
#   0.10187948  0.4722611   0.14555109 -0.03775303  0.44307336 -0.02396859
#   0.13488047  0.08917145 -0.35357177  0.28726533 -0.09574156 -0.16903903
#  -0.49219617  0.24186131 -0.07444324 -0.24883905 -0.00621465 -0.13557634
#  -0.19252487  0.29168698 -0.41692844 -0.00412344 -0.1452684   0.4820524
#  -0.14032951 -0.5991248  -0.18219689 -0.18499336  0.05411211  0.53084415
#   0.64322543  0.07308488  0.25678906  0.04230531  0.26027605 -0.3931366
#  -0.05893256 -0.21376315 -0.08284791  0.10399161  0.31551653  0.04321823
#   0.30823022 -0.16581404  0.23960981  0.28064865  0.37256092 -0.13525115
#   0.25405422  0.16331233  0.35070506  0.17672221 -0.19988753  0.43139485
#   0.03089834 -0.19419868  0.2814827   0.16373691  0.38194644  0.07412594
#  -0.12609546  0.09034806 -0.04826392  0.01008342 -0.28749815  0.06184154
#   0.20504582 -0.03953273  0.29838413  0.43131542 -0.25587967 -0.09844338
#  -0.02376167 -0.00937102  0.02770688 -0.45111272 -0.35392153  0.5126951
#   0.23245752 -0.34177086 -0.21129557  0.05677316  0.5546495  -0.08215375
#  -0.00676165 -0.39901334 -0.08919369  0.41214263 -0.08708963 -0.13582414
#  -0.63549995  0.02450114  0.01285913 -0.7164387   0.10017967  0.5590221
#  -0.01917831  0.27384567 -0.26463598 -0.57065266 -0.17330405 -0.08590028
#   0.150044   -0.205012   -0.04435221 -0.54029024 -0.1468035   0.00340941
#  -0.11050145  0.08904384 -0.32924327 -0.1312554   0.18867008 -0.19956253
#  -0.29030195  0.14432254  0.1468898  -0.11560112 -0.44139934  0.29355797
#  -0.08750477  0.18840615 -0.16270764 -0.29627475  0.03903684  0.35435188
#  -0.12955585  0.626982    0.00872159 -0.36160555  0.5047951   0.04195767
#  -0.25846726 -0.25052726  0.15559424  0.52225864 -0.251038    0.15195535
#   0.20040455 -0.21016866 -0.17603254  0.05351226  0.60669845 -0.03961951
#   0.02045462 -0.06499617 -0.02567258  0.65943205 -0.03065771  0.06455997
#  -0.3466842  -0.6839782  -0.11202467 -0.0033906  -0.05555568  0.10228321
#  -0.31626076  0.342108    0.04756577 -0.06006576 -0.08507168 -0.12329525
#  -0.12782153  0.17156093  0.03903758 -0.05223509 -0.15849629 -0.30992845
#   0.09391258  0.11996911 -0.02740262 -0.17678444  0.29328814  0.10963745
#   0.19932206 -0.4078294  -0.46068984  0.25404918  0.3977672  -0.06281538
#  -0.06987935  0.19879231  0.24662204  0.2620337  -0.47822598  0.22593321
#  -0.08057065  0.25996092 -0.20361656  0.21035475  0.54492146  0.14283516
#  -0.02409051 -0.12658672  0.02229546 -0.29530638 -0.1400619  -0.3517389
#  -0.31481612 -0.44940257 -0.08312096  0.31053114]

# %%
# !pip freeze
# !pip install gensim==4.0.0b0
# !pip install --upgrade gensim
# gensim.__version__

# %%
# from json import JSONEncoder
# class NumpyArrayEncoder(JSONEncoder):
#     def default(self, obj):
#         if isinstance(obj, numpy.ndarray):
#             return obj.tolist()
#         return JSONEncoder.default(self, obj)

# %%
from gensim.models.keyedvectors import KeyedVectors
from gensim.models import Word2Vec, KeyedVectors

# %%
list_1 = list(list_1)
list_2 = np.stack(list_2, axis=0)

# %%
gensim_models = KeyedVectors(400,count=len(list_1))
gensim_models.add_vectors(list_1,list_2)

# %%
gensim_models.save('gensim_model.model') #bin #kv

# %%
relations_left[0]
# Out:
# array([ 0.21865478,  0.2853011 ,  0.40159422,  0.3809845 ,  0.31712306,
#         0.4907502 ,  0.2699243 ,  0.26271448, -0.46574578, -0.06488804,
#         0.4244827 ,  0.3150751 ,  0.40627244,  0.4346973 ,  0.11768712,
#        -0.29141554, -0.25403723, -0.26504874, -0.47186193,  0.3830049 ,
#         0.1044362 , -0.24359064, -0.32620627,  0.50930685, -0.42501178,
#         0.49163005,  0.2547748 , -0.615411  , -0.33978832, -0.10845868,
#         0.35847124,  0.16136882,  0.41785538,  0.26463374, -0.292871  ,
#        -0.0293926 ,  0.4670544 , -0.2379936 , -0.46268576,  0.27355805,
#        -0.30974528, -0.14513108,  0.20539391, -0.3360885 , -0.29952657,
#        -0.2578046 , -0.43837047, -0.01432132,  0.44997308, -0.3131817 ,
#        -0.2063915 ,  0.26613328, -0.1419458 , -0.28814504,  0.07143813,
#         0.11462472,  0.42526415,  0.37168562, -0.01822625,  0.48426524,
#        -0.24448316,  0.31116578,  0.23402809, -0.11710633,  0.15277512,
#         0.0845698 ,  0.10585778, -0.25453472,  0.33475417, -0.3678028 ,
#         0.35000458,  0.02160965, -0.24165002,  0.01070646,  0.30206648,
#        -0.2630501 , -0.47361898, -0.12035393,  0.5285463 , -0.30187124,
#         0.34182677,  0.46171987,  0.3131562 , -0.09211794, -0.0189817 ,
#         0.12588996,  0.08285904, -0.09759646, -0.12268215, -0.2623703 ,
#         0.24301073,  0.01833374, -0.05337767, -0.11433916, -0.39152429,
#         0.30859125, -0.3104168 ,  0.2540917 , -0.1191099 , -0.2737098 ,
#         0.23759334, -0.07069322, -0.26621085, -0.25632456, -0.2505555 ,
#        -0.3619211 , -0.43333578, -0.38318086, -0.05083298, -0.2565289 ,
#         0.23779728, -0.28005388,  0.20144355,  0.3103492 ,  0.0428632 ,
#         0.16306892, -0.24525431, -0.19556113,  0.25368404, -0.13745211,
#        -0.30490178,  0.12800671,  0.2646196 , -0.20951068, -0.20817989,
#         0.0323757 , -0.23334906,  0.43771234, -0.21931615, -0.20377557,
#         0.3068918 ,  0.1320191 , -0.08328516, -0.33643937, -0.03057071,
#         0.0502977 , -0.38938218,  0.23167066,  0.22043245, -0.29188788,
#        -0.41686308, -0.41201696,  0.33496827,  0.16224185,  0.18590876,
#         0.04272934, -0.03327952,  0.26643616, -0.37648904,  0.09349915,
#         0.42691565, -0.38747945, -0.04380367,  0.07555868, -0.35974005,
#         0.45504874, -0.27644408, -0.21688214, -0.4695933 ,  0.48166057,
#        -0.29522026, -0.21160667,  0.07004372,  0.48807916,  0.33682102,
#         0.03647865, -0.23449366, -0.03919293,  0.28057688, -0.2839245 ,
#         0.3424973 , -0.37273148,  0.06172182, -0.39245957, -0.2927515 ,
#         0.17304559,  0.62911224,  0.48194683, -0.48547256, -0.14775608,
#         0.2014217 , -0.37500742, -0.14171197,  0.4686876 , -0.09365526,
#         0.16580264, -0.01957671,  0.32069388,  0.2718576 , -0.18225332,
#         0.22340815,  0.40919873, -0.30675715, -0.2358615 , -0.15911968,
#         0.28199068, -0.18905051,  0.32945883,  0.31805515, -0.13832873,
#         0.17978407, -0.20588878, -0.53866124, -0.48529866, -0.21908449,
#         0.50216514,  0.27722085,  0.09488785,  0.21611919,  0.12966138,
#        -0.28242648, -0.5743316 ,  0.19973414,  0.44689614, -0.59318846,
#         0.3726649 ,  0.02323058,  0.32427183,  0.42874274, -0.28239325,
#         0.1455821 , -0.5899727 , -0.39193133,  0.44424725,  0.52050793,
#        -0.17909387,  0.13488777, -0.0942708 , -0.40156534, -0.4182982 ,
#        -0.375948  , -0.3210814 ,  0.3506769 ,  0.24847981,  0.34996152,
#         0.36055502, -0.190696  , -0.22774854,  0.33672738,  0.05866447,
#        -0.44013137, -0.03629411, -0.36211634,  0.02064927, -0.25283223,
#        -0.24646458, -0.22467884,  0.28545666, -0.13577408, -0.31889445,
#         0.04994482, -0.11465603, -0.0007569 ,  0.11894395,  0.23556143,
#         0.34834176, -0.4233802 , -0.27007753, -0.23233399,  0.31040695,
#         0.28040922, -0.35494402, -0.2689761 ,  0.40457332,  0.11818504,
#         0.3141755 , -0.40938464, -0.4806498 ,  0.42622906,  0.39036006,
#        -0.24278253,  0.33456838, -0.22275491, -0.10210785,  0.2527059 ,
#        -0.03281231, -0.02959794, -0.1503039 ,  0.2652631 , -0.20733252,
#        -0.45543712,  0.21450792,  0.31282753, -0.19114552, -0.29286388,
#         0.00817663,  0.03031125, -0.21457626,  0.02402977,  0.24277084,
#        -0.24917227,  0.08543712,  0.18910024, -0.3889674 , -0.3955386 ,
#        -0.07395402,  0.3690958 , -0.33747897, -0.22401544,  0.28930414,
#         0.16842024,  0.16414808, -0.01099312, -0.21203864, -0.04837177,
#        -0.26618218,  0.22090487,  0.3770102 ,  0.39741063,  0.21552509,
#        -0.35982233, -0.23420325, -0.3392622 ,  0.29434055,  0.19401252,
#        -0.27785143, -0.13549359, -0.34482345, -0.2090477 , -0.23512617,
#         0.02995379,  0.18299001, -0.05565327, -0.19065349,  0.07116882,
#         0.3020527 ,  0.34851626,  0.36564943, -0.13437445,  0.07335006,
#        -0.30491343,  0.3243204 , -0.1304542 , -0.36854056, -0.20385246,
#         0.25304645,  0.10145136,  0.32006803, -0.1836063 , -0.0981193 ,
#         0.09020953, -0.02636208, -0.24501647,  0.2905837 ,  0.07233458,
#         0.21751556, -0.12481883, -0.2256566 ,  0.45901585,  0.4078103 ,
#        -0.3496841 ,  0.04169377,  0.32012355,  0.3719236 ,  0.12747037,
#         0.01072599,  0.38620707, -0.37052292, -0.2291562 ,  0.45049292,
#         0.13115917,  0.502328  ,  0.47803152,  0.14336866, -0.06368123,
#         0.08551507,  0.27142167,  0.27652866, -0.11932827,  0.3819803 ,
#         0.4124591 , -0.29224607, -0.58969766,  0.17411791,  0.2977901 ,
#        -0.31780943, -0.27641943,  0.12538157,  0.40556327, -0.0038957 ,
#        -0.3184378 , -0.19623737,  0.39531738,  0.02328415,  0.14188115,
#        -0.260441  , -0.18916374,  0.09656638,  0.35688093, -0.40320095,
#         0.10555987, -0.01516441,  0.00708778,  0.04905922, -0.14603336,
#        -0.48730615,  0.39899418, -0.18174824,  0.32732677, -0.48502034],
#       dtype=float32)

# %%
#     "written_by",
#     "has_imdb_votes",
#     "directed_by",
#     "starred_actors",
#     "has_imdb_rating",
#     "release_year",
#     "in_language",
#     "has_tags",
#     "has_genre"

# %%
# rel_types = ['written_by', 'has_imdb_votes','directed_by','starred_actors','has_imdb_rating','release_year','in_language','has_tags','has_genre']

# %%
rel_dict = {
    'written_by': relations_left[],
    'has_imdb_votes': relations_left[],
    'directed_by': relations_left[],
    'starred_actors': relations_left[],
    'has_imdb_rating': relations_left[],
    'release_year': relations_left[],
    'in_language': relations_left[],
    'has_tags': relations_left[],
    'has_genre': relations_left[]
}

# %%
## add relationships
result = gensim_models.most_similar(positive=['Kismet', relations_left[8]],topn=10)[:][:]
result
# Out:
# [('Helen_Mirren', 0.5621678233146667),
#  ('John_Lithgow', 0.5546588897705078),
#  ('Burt_Lancaster', 0.5494174361228943),
#  ('Marlene_Dietrich', 0.5394538044929504),
#  ('Ethan_Hawke', 0.5377938747406006),
#  ('Jeanne_Moreau', 0.534210741519928),
#  ('Danny_Glover', 0.5336334109306335),
#  ('Michael_Redgrave', 0.5334655046463013),
#  ('Kim_Novak', 0.5271657705307007),
#  ('Julie_Delpy', 0.5253924131393433)]

# %%
relations[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-8eb673f538fb> in <module>
# ----> 1 relations[0]
#
# NameError: name 'relations' is not defined

# %% [markdown]
# # Chatbot

# %%
from gensim.models.keyedvectors import KeyedVectors
from gensim.models import Word2Vec, KeyedVectors

# %%
re_gensim = KeyedVectors.load('gensim_model.model')
test = re_gensim.most_similar(positive=['Cobra_Woman', 'Sleep_with_Me'],topn=1)[0][0]
test
# Out:
# 'Free_Enterprise'

# %%
## first need to have the relationship in the form of embeddings 
## King + Spouse = most related entity (how the translation works)
## how translation works: (take a vector and another vector, and take the sum) 
## translation model is a model where you take left hand side and shift it by the relationship and you hope you get close to right hand side
## as opposed to rotation or another kind of vector manipulation 

## can use gensim by saying this is the lhs, this is the relationship, take them as features using positive keyword
## hoping we can play with that (positive, negative)

## if we do not have information about relationship we cannot do translation 
## it should train entities of embeddings and also train relationship and provide them 

## how big is the model 

## goal is to experiment and see where relationship is (make repository with 4 dimensions and put to github)
## configuration file, output files and have a look 
## left hand side, right hand side, try to position vectors so that when you add up lhs and relationship you get rhs
## in process you teak embedding of LHS and relationship, such that you get close to RHS 

## in the meantime, try to integrate what you have 
## you have bot interface, you have very simple prediction model of similarity
## try to integrate them — spielberg – output is most similar stuff 
## and then leveredge positive keyword of most similar method — in case query is multiple entities 
## i.e. spielberg, and jurassic park — use those as positive and get most similar 
## just to create pipeline — and then plug in relationship part once it's figured out 

## next time ideally we'll create an instance on AWS or Heroku and we can put application up there

## deadlines: 
## Beginning of April, Sunday — finish 95% of development
## I have April to do fine tuning, and have time to prepare for report and presentation 
## first of all ahve to think about what i'm going to put inside 
## I will have to have significant part talking about theoretical things I have learned

# %%
#model.wv.save_word2vec_format(entity2embedding)

# %% [markdown]
# ## Back up

# %%
# DATA_DIR = 'data/example_2'
# GRAPH_PATH = DATA_DIR + '/edges.tsv'
# MODEL_DIR = 'model_2'

#     # ==================================================================
#     # 0. PREPARE THE GRAPH
#     # the result of this step is a single file 'data/example_2/graph.tsv'
#     # ==================================================================
#     # This the graph we will be embedding.
#     # It has 10 types of nodes, or entities, and 9 types of edges, or relationships. 
#     test_edges = []
#     count=0
#     with open('kb.txt', 'r') as f: 
#         for line in f: 
#            line=line.rstrip().split("|")
#            line[0] = line[0].split(" ")
#            line[0] = "_".join(line[0])
#         #    line[2] = line[2].split(" ")
#         #    line[2] = "_".join(line[2])
#            test_edges.append(line)
#            count+=1
#            if count == 134741:
#                break
           
#     os.makedirs(DATA_DIR, exist_ok=True)
#     with open(GRAPH_PATH, 'w') as f:
#         for edge in test_edges:
#             f.write('\t'.join(edge) + '\n')
# # # # ==================================================
# # # # 1. DEFINE CONFIG
# # # # this dictionary will be used in steps 2. and 3.
# # # # ==================================================

# raw_config = dict(
#     # I/O data
#     entity_path=DATA_DIR,
#     edge_paths=[
#         DATA_DIR + '/edges_partitioned',
#     ],
#     checkpoint_path=MODEL_DIR,
#     # Graph structure
#     entities={
#         "all": {"num_partitions": 1}
#     },
#     relations=[
#         {
#             "name": "directed_by",
#             "lhs": "all",
#             "rhs": "all",
#             "operator": "complex_diagonal",
#         },
#         {
#             "name": "written_by",
#             "lhs": "all",
#             "rhs": "all",
#             "operator": "complex_diagonal",
#         },
#         {
#             "name": "starred_actors",
#             "lhs": "all",
#             "rhs": "all",
#             "operator": "complex_diagonal",
#         },
        
#         {
#             "name": "release_year",
#             "lhs": "all",
#             "rhs": "all",
#             "operator": "complex_diagonal",
#         },
#         {
#             "name": "in_language",
#             "lhs": "all",
#             "rhs": "all",
#             "operator": "complex_diagonal",
#         },
#         {
#             "name": "has_tags",
#             "lhs": "all",
#             "rhs": "all",
#             "operator": "complex_diagonal",
#         },
#         {
#             "name": "has_genre",
#             "lhs": "all",
#             "rhs": "all",
#             "operator": "complex_diagonal",
#         },
        
#         {
#             "name": "has_imdb_votes",
#             "lhs": "all",
#             "rhs": "all",
#             "operator": "complex_diagonal",
#         },
        
#         {
#             "name": "all_edges",
#             "lhs": "all",
#             "rhs": "all",
#             "operator": "complex_diagonal",
#         }
#     ],

#     dynamic_relations=False,
#     dimension=200,  
#     global_emb=False,
#     comparator="dot",
#     num_epochs=7,
#     num_uniform_negs=1000,
#     loss_fn="softmax",
#     lr=0.1,
#     regularization_coef=1e-3,
#     eval_fraction=0.,
# )

## Set Up Logging 


# # =======================================================================
# # 4. LOAD THE EMBEDDINGS
# # The final output of the process consists of a dictionary mapping each entity to its embedding

# # =======================================================================

# # entities_path = DATA_DIR + '/entity_names_entities_0.json'

# # entities_emb_path = MODEL_DIR + "/embeddings_entities.v{NUMBER_OF_EPOCHS}.h5" \
# #     .format(NUMBER_OF_EPOCHS=raw_config['num_epochs'])

# # with open(entities_path, 'r') as f:
# #     entities = json.load(f)

# # with h5py.File(entities_emb_path, 'r') as g:
# #     entity_embeddings = g['embeddings'][:]

# # entity2embedding = dict(zip(entities, entity_embeddings))
# # print('entity embeddings')
# # print(entity2embedding)

# movies_path = DATA_DIR + '/entity_names_movie_0.json'
# directors_path = DATA_DIR + '/entity_names_director_0.json'
# writers_path = DATA_DIR + '/entity_names_writer_0.json'
# actors_path = DATA_DIR + '/entity_names_starred_actor_0.json'
# years_path = DATA_DIR + '/entity_names_year_0.json'
# languages_path = DATA_DIR + '/entity_names_language_0.json'
# tags_path = DATA_DIR + '/entity_names_tags_0.json'
# genres_path = DATA_DIR + '/entity_names_genre_0.json'
# votes_path = DATA_DIR + '/entity_names_votes_0.json'
# rating_path = DATA_DIR + '/entity_names_rating_0.json'


# movie_emb_path = MODEL_DIR + "/embeddings_movie_0.v{NUMBER_OF_EPOCHS}.h5" \
#     .format(NUMBER_OF_EPOCHS=raw_config['num_epochs'])

# director_emb_path = MODEL_DIR + "/embeddings_director_0.v{NUMBER_OF_EPOCHS}.h5" \
#     .format(NUMBER_OF_EPOCHS=raw_config['num_epochs'])

# writer_emb_path = MODEL_DIR + "/embeddings_writer_0.v{NUMBER_OF_EPOCHS}.h5" \
#     .format(NUMBER_OF_EPOCHS=raw_config['num_epochs'])

# actor_emb_path = MODEL_DIR + "/embeddings_starred_actor_0.v{NUMBER_OF_EPOCHS}.h5" \
#     .format(NUMBER_OF_EPOCHS=raw_config['num_epochs'])

# year_emb_path = MODEL_DIR + "/embeddings_year_0.v{NUMBER_OF_EPOCHS}.h5" \
#     .format(NUMBER_OF_EPOCHS=raw_config['num_epochs'])

# language_emb_path = MODEL_DIR + "/embeddings_language_0.v{NUMBER_OF_EPOCHS}.h5" \
#     .format(NUMBER_OF_EPOCHS=raw_config['num_epochs'])

# tags_emb_path = MODEL_DIR + "/embeddings_tags_0.v{NUMBER_OF_EPOCHS}.h5" \
#     .format(NUMBER_OF_EPOCHS=raw_config['num_epochs'])

# genre_emb_path = MODEL_DIR + "/embeddings_genre_0.v{NUMBER_OF_EPOCHS}.h5" \
#     .format(NUMBER_OF_EPOCHS=raw_config['num_epochs'])

# votes_emb_path = MODEL_DIR + "/embeddings_votes_0.v{NUMBER_OF_EPOCHS}.h5" \
#     .format(NUMBER_OF_EPOCHS=raw_config['num_epochs'])

# rating_emb_path = MODEL_DIR + "/embeddings_rating_0.v{NUMBER_OF_EPOCHS}.h5" \
#     .format(NUMBER_OF_EPOCHS=raw_config['num_epochs'])

# with open(movies_path, 'r') as f:
#     movies = json.load(f)

# with h5py.File(movie_emb_path, 'r') as g:
#     movie_embeddings = g['embeddings'][:]

# movie2embedding = dict(zip(movies, movie_embeddings))
# # print('movie embeddings')
# # print(movie2embedding)

# with open(directors_path, 'r') as f:
#     directors = json.load(f)

# with h5py.File(director_emb_path, 'r') as g:
#     director_embeddings = g['embeddings'][:]

# director2embedding = dict(zip(directors, director_embeddings))
# # print('director embeddings')
# # print(director2embedding)

# with open(writers_path, 'r') as f:
#     writers = json.load(f)

# with h5py.File(writer_emb_path, 'r') as g:
#     writer_embeddings = g['embeddings'][:]

# writer2embedding = dict(zip(writers, writer_embeddings))
# # print('writer embeddings')
# # print(writer2embedding)

# with open(actors_path, 'r') as f:
#     actors = json.load(f)

# with h5py.File(actor_emb_path, 'r') as g:
#     actor_embeddings = g['embeddings'][:]

# actor2embedding = dict(zip(actors, actor_embeddings))
# # print('actor embeddings')
# # print(actor2embedding)

# with open(years_path, 'r') as f:
#     years = json.load(f)

# with h5py.File(year_emb_path, 'r') as g:
#     year_embeddings = g['embeddings'][:]

# year2embedding = dict(zip(years, year_embeddings))
# # print('year embeddings')
# # print(year2embedding)

# with open(languages_path, 'r') as f:
#     languages = json.load(f)

# with h5py.File(language_emb_path, 'r') as g:
#     language_embeddings = g['embeddings'][:]

# language2embedding = dict(zip(languages, language_embeddings))
# # print('language embeddings')
# # print(language2embedding)

# with open(tags_path, 'r') as f:
#     tags = json.load(f)

# with h5py.File(tags_emb_path, 'r') as g:
#     tags_embeddings = g['embeddings'][:]

# tag2embedding = dict(zip(tags, tags_embeddings))
# # print('tag embeddings')
# # print(tag2embedding)

# with open(genres_path, 'r') as f:
#     genres = json.load(f)

# with h5py.File(genre_emb_path, 'r') as g:
#     genre_embeddings = g['embeddings'][:]

# genre2embedding = dict(zip(genres, genre_embeddings))
# # print('genre embeddings')
# # print(genre2embedding)

# with open(votes_path, 'r') as f:
#     votes = json.load(f)

# with h5py.File(votes_emb_path, 'r') as g:
#     votes_embeddings = g['embeddings'][:]

# votes2embedding = dict(zip(votes, votes_embeddings))
# # print('votes embeddings')
# # print(votes2embedding)

# with open(rating_path, 'r') as f:
#     ratings = json.load(f)

# with h5py.File(rating_emb_path, 'r') as g:
#     rating_embeddings = g['embeddings'][:]

# rating2embedding = dict(zip(ratings, rating_embeddings))
# # print('rating embeddings')
# # print(rating2embedding)

# entity2embedding = {**movie2embedding, **director2embedding, **writer2embedding, **actor2embedding, **year2embedding, **language2embedding, **tag2embedding, **genre2embedding, **votes2embedding, **rating2embedding}
# print('entity embeddings')
# print(entity2embedding)
